# %% [markdown]
# ## Problem Statement

# %% [markdown]
# we are using this imaginary company called **AtliQ grants** for this project.
#
#  Now this company is a hotel chain which operates in develop various cities in India. They have hotels in 4 cities, Delhi, Mumbai , Bangalore and Hyderabad and they've been in the industry for around 20 years now. They have different types of hotels such as Atliq season, exotica , bah, palace.
#
# For example, Atliq palace is a luxurious hotel. There are other hotels such as Atliq seasons, which are in business category and they have different types of rooms like, standard,  elite, premium , presidential etc.
#
# Now a person can book a hotel via Various medium,
# 1. **AtliQ grants's own website** , so you can go to the website and book a room there.
# 2. You can also go to **third party booking website**. Such as make-your-trip , lock-trip,  tripster and so on .
#
# Booking happens through variety of mediums , that data will go into Atliq Grants booking databases, and from this database, we want to now perform data analysis because this company athlete grants is facing a major challenge from their competitors. They are losing their revenue, their market share and Atliq's management has decided to onboard data analytics, and they're going to do data informed decision-making so that they can increase their revenue .

# %% [markdown]
# Now in order to do that, you have this booking database, where all of your transactions , bookings, the revenue generated,  cancellation, all the information is stored here .
#
# Now, their Atliq's management can hire data analysts, and data analysts can perform a query directly on this database. They can write a sql query, but it may slow down this particular database and it's sufficient critical database, so you do not want to touch this database. So maybe what you can do is you can create a replica or copy, And on that copy, you perform whatever analyics you want to perform.
#
# You can either make a blind copy, or you can perform some kind of a transformation, so you can maybe performs a normalisation , aggregation ,  some type of transformation and this transformation process is called **ETL**, which is "extract transformed load" . So your extracted data from booking database, You are transforming And then you are loading it into this other database, which is also called data warehouse.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So data warehouse is the database that companies have where data analyst, data scientists will be performing their queries or their analysis. They don't perform their analysis directly on the actual database, which is a mission-critical transactional database . So this picture shows that A data analyst would perform the analysis on the data warehouse. They can build a dashboard in power BI or tablu, or they can pull this data in a Jupiter notebook. And using pandas, they can perform the data analysis, And this is what we are going to do in our project.
#
# We'll pull this data into Jupiter notebook. And will perform data analysis through pandas.
# Now the first part of the system is called **OLTB**** online transactional processing. Because here is where you store your transactional data, this is mission-critical database. You can't afford to have this database slow down. Otherwise, the booking process, which is an essential business activity, will be impacted .
# On the other hand if your data warehouse and if the data warehouse is down for 1 or 2 hours, it's OK. Because you are just performing analysis. if you have some down time in your analytics process, it's not gonna cause any revenue loss. Therefore, this second A part of the system is called **OLAP** online analytical processing. So it's the whole system where you have your data warehouse,  your ETL processes.
# This ETL processes can be written by python, so data engineer can write python code for this transformation, or they can use Apache, knifefy , talent, etc data engineering tools.

# %% [markdown]
# Now in our case,  we don't want to hold data directly from the data warehouse, just to keep things simple, we would have asked data engineers to to generate some excel files or csv files, and we will take these CSV files from data warehouse.
#
# So you're going to assume that you have all the csv files which data engineer have generated from data warehouse and using this csv file, you will pull the data in your Jupiter notebook. And you will do data analysis in Pandas.

# %% [markdown]
# ***Data Analytics Project Steps***
#
# 1. Understanding business problem.
#  So in our case, obviously **Atliq Grants** is using revenues,it is using market share. So the business problem that we have is we want to get answers on key questions like, what is my occupancy Percentage,  where exactly in which city I am using more revenue than the other cities.Business managers have so many questions.So that's your business problem.
# 2. Data collection and understanding.
#  And once you understand the business problem, you will do data collection and data understanding, so in our case, data warehouse have all the data that we need it has been exported to csv files. So we got our data in terms of csv file.
# 2. Data cleaning and exploration.
#  The data that you get from data warehouse might not cleaned.It might be messy. There might be errors. There might be issue, so you have to perform some cleaning and then you explore the data.
# 4. Dta transformation.
#  You also can perform data transformation, because for your  analytic needs, you might have to transform data in a certain way .
# 5. Collecting insights.
#  The last step is collecting insights .

# %% [markdown]
# ![Screenshot 2025-08-20 123946.png](<attachment:Screenshot 2025-08-20 123946.png>)

# %% [markdown]
# ***Data Analyst*** -> ***Data Engineer*** -> ***CSV or EXCEL file*** -> ***Jupyter notebook*** -> ***Data Analysis*** -> ***Pandas***
